# %%
import json
import pandas as pd
import re
import os 
import logging


import sys
sys.path.append('../')
#from src.constants import SCHEMAS_DIR
from src.utils import get_all_schema
from tableschema import Schema

from typing import List

# %%
path2schemas = '../schemas/'
path2test_schemas = '../tests/schemas/'
path2tables_history = 'tables_history.csv'
path2variables_history = 'variables_history.csv'

# %%
DEFAULT_CREATED = ''
DEFAULT_DELETED = ''
DEFAULT_MISSINGS = []

# %%
def add_tables_history(
    schemas_dir: str, 
    tables_history_filename: str,
    save: bool = True) -> List[Schema]:
    """
    Add tables history to schemas 
    """
    new_schemas = []
    schemas = get_all_schema(schemas_dir=schemas_dir)
    tables_history_df = pd.read_csv(tables_history_filename)
    ## harmonize the unkown year part in the table names (XX for kwikly != aa_nn for the schema)
    tables_history_df['var'] = tables_history_df['var'].apply(lambda x: re.sub('XX', 'aa_nn', x))
    for schema in schemas:
        table_name = schema.descriptor['name']
        logging.info("Ajout de l'historique pour la table '{}'".format(table_name))
        table_produit = schema.descriptor['produit']
        table_history = tables_history_df.loc[tables_history_df['var'] == table_name, :]
        if len(table_history) == 0:
            table_history_dic = {
            'dateCreated': DEFAULT_CREATED, 
            'dateDeleted': DEFAULT_DELETED,
            'dateMissing': DEFAULT_MISSINGS}
        else:
            if pd.isna(table_history['missings'].values[0]):
                dateMissing = DEFAULT_MISSINGS
            else:
                dateMissing = str(table_history['missings'].values[0]).split('_')
            table_history_dic = {
                'dateCreated': str(table_history['created'].values[0]), 
                'dateDeleted': str(table_history['deleted'].values[0]),
                'dateMissing': dateMissing}
        schema.descriptor['history'] = table_history_dic
        schema.commit()
        if save:
            if re.search('PMSI', table_produit) is not None:
                save_path = os.path.join(schemas_dir, 'PMSI', table_produit, table_name)+'.json'
            else:
                save_path = os.path.join(schemas_dir, table_produit, table_name)+'.json'
            schema.save(save_path, ensure_ascii=False)
        new_schemas.append(schema)
    return new_schemas

def add_variables_history(
    schemas_dir: str, 
    variables_history_filename: str,
    save: bool = True,
    verbose=False) -> List[Schema]:
    """
    Add variables history to schemas 
    """
    new_schemas = []
    schemas = get_all_schema(schemas_dir=schemas_dir)
    variables_history_df = pd.read_csv(variables_history_filename)
    ## harmonize the unkown year part in the table names (XX for kwikly != aa_nn for the schema)
    variables_history_df['table'] = variables_history_df['table'].apply(lambda x: re.sub('XX', 'aa_nn', x))
    for schema in schemas:
        table_name = schema.descriptor['name']
        table_produit = schema.descriptor['produit']
        table_history = variables_history_df.loc[variables_history_df['table'] == table_name, :]
        logging.info("-----\n Ajout de l'historique pour la table '{}'".format(table_name))
        for var_name in schema.field_names:
            if verbose:
                logging.info("Ajout de l'historique pour la variable '{}'".format(var_name))
            var_history = table_history.loc[table_history['var'] == var_name, :]
            if len(var_history) == 0:
                var_history_dic = {
                    'dateCreated': DEFAULT_CREATED, 
                    'dateDeleted': DEFAULT_DELETED,
                    'dateMissing': DEFAULT_MISSINGS}
            else:
                if pd.isna(var_history['missings'].values[0]):
                    dateMissing = DEFAULT_MISSINGS
                else:
                    dateMissing = str(var_history['missings'].values[0]).split('_')
                var_history_dic = {
                    'dateCreated': str(var_history['created'].values[0]), 
                    'dateDeleted': str(var_history['deleted'].values[0]),
                    'dateMissing': dateMissing}
            schema.update_field(var_name, var_history_dic)
        schema.commit()
        new_schemas.append(schema)
        if save:
            if re.search('PMSI', table_produit) is not None:
                save_path = os.path.join(schemas_dir, 'PMSI', table_produit, table_name)+'.json'
            else:
                save_path = os.path.join(schemas_dir, table_produit, table_name)+'.json'
            schema.save(save_path, ensure_ascii=False)
    return new_schemas


def rm_tables_fields(
    schemas_dir: str, 
    fields_to_rm: List[str],
    save: bool = True,
    verbose: bool = False) -> List[Schema]:
    """
    Remove some fields from the schemas
    """
    new_schemas = []
    schemas = get_all_schema(schemas_dir=schemas_dir)
    for schema in schemas:
        table_name = schema.descriptor['name']
        if verbose:
            logging.info("Suppresion des champs {} pour la table '{}'".format(fields_to_rm, table_name))
        table_produit = schema.descriptor['produit']
        
        for f in fields_to_rm:
            schema.descriptor.pop(f, 0)
        schema.commit()
        if save:
            if re.search('PMSI', table_produit) is not None:
                save_path = os.path.join(schemas_dir, 'PMSI', table_produit, table_name)+'.json'
            else:
                save_path = os.path.join(schemas_dir, table_produit, table_name)+'.json'
            schema.save(save_path, ensure_ascii=False)
        new_schemas.append(schema)
    return new_schemas

def rm_variables_fields(
    schemas_dir: str, 
    fields_to_rm: List[str],
    save: bool = True,
    verbose=False) -> List[Schema]:
    """
    Remove some fields from the schema
    """
    new_schemas = []
    schemas = get_all_schema(schemas_dir=schemas_dir)
    
    for schema in schemas:
        table_name = schema.descriptor['name']
        table_produit = schema.descriptor['produit']
        if verbose:
            logging.info("-----\n Suppresion des champs {} pour la table '{}'".format(fields_to_rm, table_name))
        for i, var_name in enumerate(schema.field_names):
            #if verbose:
            #    logging.info("Suppression des champs pour la variable '{}'".format(var_name))
            for f in fields_to_rm:
                schema.descriptor['fields'][i].pop(f, 0)
        schema.commit()
        new_schemas.append(schema)
        if save:
            if re.search('PMSI', table_produit) is not None:
                save_path = os.path.join(schemas_dir, 'PMSI', table_produit, table_name)+'.json'
            else:
                save_path = os.path.join(schemas_dir, table_produit, table_name)+'.json'
            schema.save(save_path, ensure_ascii=False)
    return new_schemas

# %% [markdown]
# # src schemas history addition

# %%
table_schemas = add_tables_history(path2schemas, 'tables_history.csv', save=True)
var_history = add_variables_history(path2schemas, 'variables_history.csv', save=True)
# Out:
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_BEN_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_IBA_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'CT_DEP_AAAA_GN'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'CT_IDE_AAAA_GN'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'CT_IND_AAAA_GN'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'KI_CCI_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'KI_ECD_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_ANO_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_ARO_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_BIO_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_CAM_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_CPT_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_DCT_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_DTR_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_ETE_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_INV_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_LOT_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_PHA_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_PRS_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_RAT_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_TIP_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_TRS_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'ER_UCD_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_BIO_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_CAM_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_DTR_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_INV_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_PHA_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_PRS_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_RAT_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_TIP_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_TRS_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'NS_UCD_F'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'DA_PRA_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_ACS_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_ETM_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_IMB_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_MAT_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_MTT_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'IR_ORC_R'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnD'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnDMPA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnDMPP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnEHPA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFH'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFI'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFL'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnGRE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnGRP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMED'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMEDATU'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMEDCHL'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnS'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnCSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnD'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnDIALP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnDMIP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFASTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFBSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFCSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFH'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFHSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFI'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFL'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFLSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFMSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFPSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnGV2018'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnIVG'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMED'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMEDATU'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMEDTHROMBO'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnPIE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnPORG'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnUM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnUPGV'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnVALO'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnVALOACE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnZ'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnCCAM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFH'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFI'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFL'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnISOCONT'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnR3A'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnR3AD'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnRSA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnRSAD'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnS'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCCAM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCSARR'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnD'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnE'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFA'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFASTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFB'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFBSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFCSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFH'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFI'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFL'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFLSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFM'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFMSTC'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFP'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnGME'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnLEG'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnMED'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnMEDATU'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnS'
# 2019-09-02 15:10:21 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnSTC'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_BEN_R'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_IBA_R'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_DEP_AAAA_GN'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_IDE_AAAA_GN'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_IND_AAAA_GN'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'KI_CCI_R'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'KI_ECD_R'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ANO_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ARO_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_BIO_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_CAM_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_CPT_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_DCT_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_DTR_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ETE_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_INV_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_LOT_F'
# 2019-09-02 15:10:22 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_PHA_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_PRS_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_RAT_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_TIP_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_TRS_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_UCD_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_BIO_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_CAM_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_DTR_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_INV_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_PHA_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_PRS_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_RAT_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_TIP_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_TRS_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_UCD_F'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'DA_PRA_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_ACS_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_ETM_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_IMB_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_MAT_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_MTT_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_ORC_R'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_HADaa_nnA'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_HADaa_nnB'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_HADaa_nnC'
# 2019-09-02 15:10:23 :: INFO :: -----
#  Ajout de l'historique pour la table 'T
:: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnSTC'

# %% [markdown]
# # test schemas history addition

# %%
table_schemas = add_tables_history(path2test_schemas, 'tables_history.csv', save=True)
var_history = add_variables_history(path2test_schemas, 'variables_history.csv', save=True)
# Out:
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_BEN_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_IBA_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'CT_DEP_AAAA_GN'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'CT_IDE_AAAA_GN'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'CT_IND_AAAA_GN'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'KI_CCI_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'KI_ECD_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_ANO_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_ARO_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_BIO_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_CAM_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_CPT_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_DCT_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_DTR_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_ETE_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_INV_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_LOT_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_PHA_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_PRS_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_RAT_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_TIP_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_TRS_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'ER_UCD_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_BIO_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_CAM_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_DTR_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_INV_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_PHA_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_PRS_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_RAT_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_TIP_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_TRS_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'NS_UCD_F'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'DA_PRA_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_ACS_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_ETM_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_IMB_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_MAT_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_MTT_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'IR_ORC_R'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnB'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnD'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnDMPA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnDMPP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnE'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnEHPA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFB'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFH'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFI'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFL'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFM'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnFP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnGRE'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnGRP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMED'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMEDATU'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnMEDCHL'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnS'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_HADaa_nnSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnB'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnCSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnD'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnDIALP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnDMIP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnE'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFA'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFASTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFB'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFBSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFCSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFH'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFHSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFI'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFL'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFLSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFM'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFMSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFP'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnFPSTC'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnGV2018'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnIVG'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMED'
# 2019-09-02 15:10:26 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMEDATU'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnMEDTHROMBO'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnPIE'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnPORG'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnUM'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnUPGV'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnVALO'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnVALOACE'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_MCOaa_nnZ'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnCCAM'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnE'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFA'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFB'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFH'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFI'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFL'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFM'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnFP'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnISOCONT'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnR3A'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnR3AD'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnRSA'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnRSAD'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnS'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_RIPaa_nnSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnB'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCCAM'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCSARR'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnCSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnD'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnE'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFA'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFASTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFB'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFBSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFCSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFH'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFI'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFL'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFLSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFM'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFMSTC'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnFP'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnGME'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnLEG'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnMED'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnMEDATU'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnS'
# 2019-09-02 15:10:27 :: INFO :: Ajout de l'historique pour la table 'T_SSRaa_nnSTC'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_BEN_R'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_IBA_R'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_DEP_AAAA_GN'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_IDE_AAAA_GN'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'CT_IND_AAAA_GN'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'KI_CCI_R'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'KI_ECD_R'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ANO_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ARO_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_BIO_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_CAM_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_CPT_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_DCT_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_DTR_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_ETE_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_INV_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_LOT_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_PHA_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_PRS_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_RAT_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_TIP_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_TRS_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'ER_UCD_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_BIO_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_CAM_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_DTR_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_INV_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_PHA_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_PRS_F'
# 2019-09-02 15:10:28 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_RAT_F'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_TIP_F'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_TRS_F'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'NS_UCD_F'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'DA_PRA_R'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_ACS_R'
# 2019-09-02 15:10:29 :: INFO :: -----
#  Ajout de l'historique pour la table 'IR_ETM_R'
# 2019-09-02 15:10:29 :: INFO :: -----
:: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnFP'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnGME'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnLEG'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnMED'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnMEDATU'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnS'
# 2019-09-02 15:10:31 :: INFO :: -----
#  Ajout de l'historique pour la table 'T_SSRaa_nnSTC'

# %% [markdown]
# ## Remove fields from schemas

# %%
table_schemas = rm_tables_fields(path2schemas, ['history'], save=True)
variables_history = rm_variables_fields(path2schemas, ['dateDeleted', 'dateCreated', 'dateMissing'])
# Out:
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_BEN_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_IBA_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_DEP_AAAA_GN'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_IDE_AAAA_GN'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_IND_AAAA_GN'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'KI_CCI_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'KI_ECD_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ANO_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ARO_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_BIO_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_CAM_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_CPT_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_DCT_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_DTR_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ETE_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_INV_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_LOT_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_PHA_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_PRS_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_RAT_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_TIP_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_TRS_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_UCD_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_BIO_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_CAM_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_DTR_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_INV_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_PHA_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_PRS_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_RAT_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_TIP_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_TRS_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_UCD_F'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'DA_PRA_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ACS_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ETM_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_IMB_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_MAT_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_MTT_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ORC_R'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnA'
# 2019-07-15 09:36:27 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnD'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnDMPA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnDMPP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnEHPA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFH'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFI'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFL'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnGRE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnGRP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMED'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMEDATU'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMEDCHL'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnS'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnCSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnD'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnDIALP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnDMIP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFASTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFBSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFCSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFH'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFHSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFI'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFL'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFLSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFMSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFPSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnGV2018'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnIVG'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMED'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMEDATU'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMEDTHROMBO'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnPIE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnPORG'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnUM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnUPGV'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnVALO'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnVALOACE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnZ'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnCCAM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFH'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFI'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFL'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnISOCONT'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnR3A'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnR3AD'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnRSA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnRSAD'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnS'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCCAM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCSARR'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnD'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnE'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFA'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFASTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFB'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFBSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFCSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFH'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFI'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFL'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFLSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFM'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFMSTC'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFP'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnGME'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnLEG'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnMED'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnMEDATU'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnS'
# 2019-07-15 09:36:28 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnSTC'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_BEN_R'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_IBA_R'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_DEP_AAAA_GN'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_IDE_AAAA_GN'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_IND_AAAA_GN'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'KI_CCI_R'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'KI_ECD_R'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ANO_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ARO_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_BIO_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_CAM_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_CPT_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_DCT_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_DTR_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ETE_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_INV_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_LOT_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_PHA_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_PRS_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_RAT_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_TIP_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_TRS_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_UCD_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_BIO_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_CAM_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_DTR_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_INV_F'
# 2019-07-15 09:36:28 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_PHA_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_PRS_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_RAT_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_TIP_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_TRS_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_UCD_F'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'DA_PRA_R'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_ACS_R'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_ETM_R'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_IMB_R'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 
:: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T_SSRaa_nnMEDATU'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T_SSRaa_nnS'
# 2019-07-15 09:36:29 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T_SSRaa_nnSTC'

# %% [markdown]
# ## Remove fields from test schemas

# %%
table_schemas = rm_tables_fields(path2test_schemas, ['history'], save=True)
variables_history = rm_variables_fields(path2test_schemas, ['dateDeleted', 'dateCreated', 'dateMissing'])
# Out:
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_BEN_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_IBA_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_DEP_AAAA_GN'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_IDE_AAAA_GN'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'CT_IND_AAAA_GN'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'KI_CCI_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'KI_ECD_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ANO_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ARO_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_BIO_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_CAM_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_CPT_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_DCT_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_DTR_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_ETE_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_INV_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_LOT_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_PHA_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_PRS_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_RAT_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_TIP_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_TRS_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'ER_UCD_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_BIO_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_CAM_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_DTR_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_INV_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_PHA_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_PRS_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_RAT_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_TIP_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_TRS_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'NS_UCD_F'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'DA_PRA_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ACS_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ETM_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_IMB_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_MAT_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_MTT_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'IR_ORC_R'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnD'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnDMPA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnDMPP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnEHPA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFH'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFI'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFL'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnFP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnGRE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnGRP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMED'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMEDATU'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnMEDCHL'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnS'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_HADaa_nnSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnCSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnD'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnDIALP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnDMIP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFASTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFBSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFCSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFH'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFHSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFI'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFL'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFLSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFMSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnFPSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnGV2018'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnIVG'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMED'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMEDATU'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnMEDTHROMBO'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnPIE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnPORG'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnUM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnUPGV'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnVALO'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnVALOACE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_MCOaa_nnZ'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnCCAM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFH'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFI'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFL'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnFP'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnISOCONT'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnR3A'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnR3AD'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnRSA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnRSAD'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnS'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_RIPaa_nnSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCCAM'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCSARR'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnCSTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnD'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnE'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFA'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFASTC'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFB'
# 2019-07-15 09:36:35 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFBSTC'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFC'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFCSTC'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFH'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFI'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFL'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFLSTC'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFM'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFMSTC'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnFP'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnGME'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnLEG'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnMED'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnMEDATU'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnS'
# 2019-07-15 09:36:36 :: INFO :: Suppresion des champs ['history'] pour la table 'T_SSRaa_nnSTC'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_BEN_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_IBA_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_DEP_AAAA_GN'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_IDE_AAAA_GN'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'CT_IND_AAAA_GN'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'KI_CCI_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'KI_ECD_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ANO_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ARO_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_BIO_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_CAM_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_CPT_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_DCT_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_DTR_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_ETE_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_INV_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_LOT_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_PHA_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_PRS_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_RAT_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_TIP_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_TRS_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'ER_UCD_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_BIO_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_CAM_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_DTR_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_INV_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_PHA_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_PRS_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_RAT_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_TIP_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_TRS_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'NS_UCD_F'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'DA_PRA_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_ACS_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_ETM_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_IMB_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_MAT_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_MTT_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'IR_ORC_R'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T_HADaa_nnA'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T_HADaa_nnB'
# 2019-07-15 09:36:36 :: INFO :: -----
#  Suppresion des champs ['dateDeleted', 'dateCreated', 'dateMissing'] pour la table 'T