# %%
import pandas as pd
import numpy as np
import re
import os

import sys
sys.path.append('../')
#from src.constants import SCHEMAS_DIR
from src.utils import get_all_schema
from tableschema import Schema

from typing import List

# %%
path2schemas = '../schemas/'
path2test_schemas = '../tests/schemas/'
path2tables_history = 'tables_history.csv'
path2variables_history = 'variables_history.csv'

# %%
def change_field(
    schemas_dir: str,
    var_name_regex : str,
    replaced_field_name : str,
    replacing_field_content: str,
    filtered_in_produits : List[str] = [] ,
    verbose : int = 1,
    save : bool = True) -> List[Schema]:
    """
    Description: Change all fields in given filtered products when variables names match a given regex
    """
    new_schemas = []
    schemas = get_all_schema(schemas_dir=schemas_dir)
    
    for schema in schemas:
        table_name = schema.descriptor['name']
        table_produit = schema.descriptor['produit']
        table_variables = schema.descriptor['fields']
        #print(table_produit)
        if (table_produit in filtered_in_produits) | (filtered_in_produits == []):
            if verbose >= 2:
                print(table_name)
            for var in table_variables:
                if re.search(var_name_regex, var['name']) is not None:
                    if verbose >= 1:    
                        print(table_name + '__' + var['name'])
                    replacing_field = {replaced_field_name: replacing_field_content}
                    schema.update_field(var['name'], replacing_field)
                    schema.commit()
        new_schemas.append(schema)
        if save:
            if re.search('PMSI', table_produit) is not None:
                save_path = os.path.join(schemas_dir, 'PMSI', table_produit, table_name)+'.json'
            else:
                save_path = os.path.join(schemas_dir, table_produit, table_name)+'.json'
            schema.save(save_path, ensure_ascii=False)
    return new_schemas

# %%
schemas_dir = path2schemas

filtered_in_produits = []
var_name_regex = '_NBJ$'
replacing_field_content = '5'
replaced_field_name = 'length'

# %%
schemas_w_good_ret = change_field(
    schemas_dir=schemas_dir,
    var_name_regex=var_name_regex,
    replacing_field_content=replacing_field_content,
    replaced_field_name=replaced_field_name, 
    filtered_in_produits=filtered_in_produits,
    save=True)
# Out:
# T_HADaa_nnB__SEJ_NBJ
# T_HADaa_nnB__SEQ_NBJ
# T_HADaa_nnB__SEQ_SEJ_NBJ
# T_HADaa_nnB__SSEQ_NBJ
# T_HADaa_nnB__SSEQ_SEQ_NBJ
# T_HADaa_nnGRE__GHT_NBJ
# T_HADaa_nnGRP__GHT_NBJ
# T_HADaa_nnS__SEJ_NBJ
# T_MCOaa_nnB__BEH_NBJ
# T_MCOaa_nnB__EXB_NBJ
# T_MCOaa_nnB__SEJ_NBJ
# T_RIPaa_nnRSA__SEQ_COU_NBJ
# T_RIPaa_nnRSA__PRE_JOU_NBJ
# T_RIPaa_nnRSA__PRE_DEM_JOU_NBJ
# T_RIPaa_nnRSA__THE_ISO_NBJ
# T_RIPaa_nnS__SEJ_NBJ
# T_SSRaa_nnB__EXB_NBJ
# T_SSRaa_nnB__EXH_NBJ
# T_SSRaa_nnS__SEJ_NBJ

# %%
# check for MCO_C
schemas_w_good_ret[65].descriptor
# Out:
# {'fields': [{'name': 'COH_NAI_RET',
#    'description': 'Code retour contrôle « Cohérence date naissance »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'COH_SEX_RET',
#    'description': 'Code retour contrôle « Cohérence sexe »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'DAT_RET',
#    'description': "Code retour contrôle «\xa0date de référence» (date d'entrée)",
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'ENT_DAT',
#    'description': "Date d'entrée du séjour PMSI",
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'ETA_NUM',
#    'description': 'Numéro FINESS e-PMSI',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'ETA_NUM_RET',
#    'description': 'Code retour contrôle «N° FINESS d’inscription e-PMSI«',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2017',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'EXE_SOI_AMD',
#    'description': "Date d'entrée du séjour PMSI au format année + mois",
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'EXE_SOI_AMF',
#    'description': 'Date de sortie du séjour PMSI au format année + mois',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'EXE_SOI_DTD',
#    'description': "Date d'entrée du séjour PMSI (date)",
#    'type': 'date',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'EXE_SOI_DTF',
#    'description': 'Date de sortie du séjour PMSI (date)',
#    'type': 'date',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'FHO_RET',
#    'description': 'Code retour «\xa0fusion ANO HOSP et HOSP PMSI\xa0»',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'FOR_NUM',
#    'description': 'N° format',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2008',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'HOS_NN_MAM',
#    'description': "Hospitalisation d'un nouveau-né auprès de la mère",
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'HOS_NNE_RET',
#    'description': "Code retour contrôle « Hospitalisation d'un nouveau-né auprès de la mère »",
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'HOS_ORG_RET',
#    'description': "Code retour contrôle « Hospitalisation pour prélèvement d'organe »",
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'HOS_PLO',
#    'description': "Hospitalisation pour prélèvement d'organe",
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NAI_RET',
#    'description': 'Code retour contrôle «\xa0date de naissance\xa0»',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NIR_ANO_17',
#    'description': 'N° anonyme',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NIR_ANO_MAM',
#    'description': 'N° anonyme mère-enfant',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NIR_RET',
#    'description': 'Code retour contrôle «\xa0n° sécurité sociale\xa0»',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NUM_DAT_AT',
#    'description': 'Numéro accident du travail ou date d’accident de droit commun',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'NUM_DAT_AT_RET',
#    'description': 'Code retour contrôle «\xa0Numéro accident du travail ou date d’accident de droit commun«',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'ORG_CPL_NUM',
#    'description': 'N° d’organisme complémentaire',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'ORG_CPL_NUM_RET',
#    'description': 'Code retour contrôle «\xa0N° d’organisme complémentaire«',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'PMS_RET',
#    'description': 'Code retour «\xa0fusion ANO PMSI et fichier PMSI\xa0»',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'RNG_BEN',
#    'description': 'Rang du bénéficiaire ',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'RNG_BEN_RET',
#    'description': 'Code retour contrôle « Rang du bénéficiaire »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'RNG_NAI',
#    'description': 'Rang de naissance ',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'RNG_NAI_RET',
#    'description': 'Code retour contrôle « Rang de naissance »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2015',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'RSA_NUM',
#    'description': 'N° séquentiel dans fichier PMSI',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SEJ_MER_RET',
#    'description': 'Code retour contrôle « N° administratif de séjour de la mère »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2013',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SEJ_NUM',
#    'description': 'N° de séjour',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SEJ_RET',
#    'description': 'Code retour contrôle «\xa0n° d’identification administratif de séjour »',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SEX_RET',
#    'description': 'Code retour contrôle «\xa0sexe\xa0»',
#    'type': 'boolean',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SOR_ANN',
#    'description': 'Année de sortie ',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SOR_DAT',
#    'description': 'Date de sortie du séjour PMSI',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2009',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'SOR_MOI',
#    'description': 'Mois de sortie',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2006',
#    'dateDeleted': '2017',
#    'dateMissing': []},
#   {'name': 'VID_HOSP_FOR',
#    'description': 'N° format VID-HOSP',
#    'type': 'string',
#    'nomenclature': '-',
#    'length': None,
#    'format': 'default',
#    'dateCreated': '2008',
#    'dateDeleted': '2017',
#    'dateMissing': []}],
#  'name': 'T_MCOaa_nnC',
#  'title': 'NIR patient et Dates de soin',
#  'description': 'Champ : Public et Privé',
#  'produit': 'PMSI MCO',
#  'missingValues': [''],
#  'primaryKey': ['ETA_NUM', 'RSA_NUM'],
#  'foreignKeys': [{'fields': ['ETA_NUM', 'RSA_NUM'],
#    'reference': {'resource': 'T_MCOaa_nnB', 'fields': ['ETA_NUM', 'RSA_NUM']},
#    'description': 'Bidirectionnel'},
#   {'fields': 'NIR_ANO_17',
#    'reference': {'resource': 'IR_BEN_R', 'fields': 'BEN_NIR_PSA'}}],
#  'history': {'dateCreated': '2006', 'dateDeleted': '2017', 'dateMissing': []}}
