# %%
import os

# %%
os.chdir('..')

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
df = pd.read_csv("nomenclatures/ORAREf//NU_UCD_R.csv", sep=';')
#df[["RGM_GRG_COD", "RGM_COD"]].duplicated().sum()
df
# Out:
#       UCD_UCD_COD  UCD_PCD_COD  UCD_SVT_COD  UCD_INS_TOP  \
# 0         9231824            0            0            0
# 1         9232120            0            0            0
# 2         9232137            0            0            0
# 3         9232143            0            0            0
# 4         9232315            0            0            0
# 5         9233214            0            0            0
# 6         9233527            0            0            0
# 7         9233680            0            0            0
# 8         9234047            0            0            0
# 9         9234225            0            0            0
# 10        9234254            0            0            0
# 11        9236247            0            0            0
# 12        9238861            0            0            0
# 13        9239145            0            0            0
# 14        9239228            0            0            0
# ...
